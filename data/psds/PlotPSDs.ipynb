# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
matplotlib.rcParams['figure.figsize'] = (8,6)
matplotlib.rcParams['xtick.labelsize'] = 20.0
matplotlib.rcParams['ytick.labelsize'] = 20.0
matplotlib.rcParams['axes.labelsize'] = 25.0
matplotlib.rcParams['legend.fontsize'] = 19.0
matplotlib.rcParams['font.family']= 'Times New Roman'
matplotlib.rcParams['font.sans-serif']= ['Bitstream Vera Sans']
matplotlib.rcParams['text.usetex']= True
matplotlib.rcParams['mathtext.fontset']= 'stixsans'

# %%
AdvVirgoASD=np.genfromtxt("AdvVirgo-ASD.txt")
AdvVirgoDesignASD=np.genfromtxt("AdvVirgoDesign-ASD.txt")

aLIGODesignKissel=np.genfromtxt("aLIGODesign_Kissel.txt")
aLIGO=np.genfromtxt("aLIGO.txt")
aLIGOZeroDetHighPowerASD=np.genfromtxt("aLIGOZeroDetHighPower-ASD.txt")

Aplus=np.genfromtxt("A+.txt")
Aplusplus=np.genfromtxt("A++.txt")
AplusDesignKissel=np.genfromtxt("AplusDesign_Kissel.txt")

CE1=np.genfromtxt("CE1.txt")
CE2narrow=np.genfromtxt("CE2 narrow.txt")
CE2wide=np.genfromtxt("CE2 wide.txt")

ETB=np.genfromtxt("ET-B.txt")
ETD=np.genfromtxt("ET-D.txt")

quantumGEO1=np.genfromtxt("quantumGEO1.txt")
quantumGEO2=np.genfromtxt("quantumGEO2.txt")

Voyager=np.genfromtxt("Voyager.txt")
Vrt=np.genfromtxt("Vrt.txt")

O2170817=np.genfromtxt("/home/aaron.zimmerman/working/O2/2017/August/G298048/ProductionPSDs/BayesWave_PSD_L1_IFO0_BWv3_psd.dat")

# %%
plt.plot(AdvVirgoDesignASD[:,0],AdvVirgoDesignASD[:,1],label='AdvVirgoDesignASD')
#plt.plot(aLIGODesignKissel[:,0],aLIGODesignKissel[:,1],label='aLIGODesignKissel')
plt.plot(aLIGOZeroDetHighPowerASD[:,0],aLIGOZeroDetHighPowerASD[:,1],label='aLIGOZeroDetHighPowerASD')
plt.plot(Aplus[:,0],Aplus[:,1],label='Aplus')
plt.plot(Aplusplus[:,0],Aplusplus[:,1],label='Aplusplus')
plt.plot(AplusDesignKissel[:,0],AplusDesignKissel[:,1],label='AplusDesignKissel')

#plt.plot(Voyager[:,0],Voyager[:,1],label='Voyager')

plt.plot(ETD[:,0],ETD[:,1],label='ETD')

plt.plot(CE1[:,0],CE1[:,1],label='CE1')
plt.plot(CE2wide[:,0],CE2wide[:,1],label='CE2wide')

plt.plot(O2170817[:,0],np.sqrt(O2170817[:,1]),label='O2170817')

plt.yscale('log')
#plt.xscale('log')
plt.xlim(1000,4096)
plt.ylim(1e-25,1e-22)
plt.xlabel('frequency (Hz)')
plt.ylabel('Power spectral density (Hz$^{-1}$)')
plt.legend(bbox_to_anchor=(1., 0.5))
plt.show()
